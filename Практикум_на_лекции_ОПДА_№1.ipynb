# %% [markdown]
# <a href="https://colab.research.google.com/github/MarinaSokolova111/Proo1/blob/main/%D0%9F%D1%80%D0%B0%D0%BA%D1%82%D0%B8%D0%BA%D1%83%D0%BC_%D0%BD%D0%B0_%D0%BB%D0%B5%D0%BA%D1%86%D0%B8%D0%B8_%D0%9E%D0%9F%D0%94%D0%90_%E2%84%961.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np


x = np.arange(0, np.pi*2, 0.05)
y = np.sin(x)
plt.plot(x, y)

# %%
from numpy import *
from pylab import *


x = linspace(-3, 3, 30)
y = x**2
plot(x, y, 'r.')
show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math


x = np.arange(0, np.pi*2, 0.05)
y = np.sin(x)
fig = plt.figure()

ax = fig.add_axes([0, 0, 1, 1])
ax.plot(x, y)
ax.set_title("Тригонометрическая функция")
ax.set_xlabel("Угол")
ax.set_ylabel("sin()")

plt.show()

# %%
import matplotlib.pyplot as plt


y = [1, 4, 9, 16, 25, 36, 49, 64]
x1 = [1, 16, 30, 42, 55, 68, 77, 88]
x2 = [1, 6, 12, 18, 28, 40, 52, 65]

fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])

l1 = ax.plot(x1, y, 'bs--')
l2 = ax.plot(x2, y, 'ro-')

ax.legend(labels = ('tv', 'Smartplhone'), loc = 'lower right')
ax.set_title('Advertisment effect on sales')
ax.set_xlabel("medium")
ax.set_ylabel("sales")

plt.show()

# %%
import matplotlib.pyplot as plt


plt.plot([1, 2, 3])
plt.subplot(211)
plt.plot(range(12))
plt.subplot(212, facecolor='r')
plt.plot(range(12))

# %%
import matplotlib.pyplot as plt


fig = plt.figure()
ax1 = fig.add_subplot(111)
ax1.plot([1, 2, 3])
ax2 = fig.add_subplot(221, facecolor = 'y')
ax2.plot([1, 2, 3])

# %%
import matplotlib.pyplot as plt
import numpy as np
import math


x = np.arange(0, np.pi*2, 0.05)
fig = plt.figure()
axes1 = fig.add_axes([0.1, 0.1, 0.8, 0.8])
axes2 = fig.add_axes([0.55, 0.55, 0.3, 0.3])

y = np.sin(x)
axes1.plot(x, y, 'b')
axes2.plot(x, np.cos(x), 'r')
axes1.set_title('sin')
axes1.set_title('cosin')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 


fig,a = plt.subplots(2, 2)
x = np.arange(1, 5)
a[0][0].plot(x, x*x)
a[0][0].set_title('square')
a[0][1].plot(x, np.sqrt(x))
a[0][1].set_title('square root')
a[1][0].plot(x, np.exp(x))
a[1][0].set_title('exp')
a[1][1].plot(x, np.log10(x))
a[1][1].set_title('log')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np 


a1 = plt.subplot2grid((3,3), (0, 0), colspan = 2)
a2 = plt.subplot2grid((3,3), (0, 2), rowspan = 3)
a3 = plt.subplot2grid((3,3), (1, 0),  rowspan = 3, colspan = 2)

x = np.arange(1, 10)
a2.plot(x, x*x, 'ms--')
a2.set_title("square")
a1.plot(x, np.exp(x), 'go-')
a1.set_title('exp', )
a3.plot(x, np.log(x), 'rv')
a3.set_title('log')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt


fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
student = [23, 17, 35, 29, 12]
ax.bar(langs, student)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np


date = [[30, 25, 50, 20],
[40, 23, 51, 17],
[35, 22, 45, 19]]
X = np.arange(4)
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.bar(X + 0.00, date[0], color = 'b', width = 0.25)
ax.bar(X + 0.25, date[1], color = 'g', width = 0.25)
ax.bar(X + 0.50, date[2], color = 'r', width = 0.25)
# Out:
# <BarContainer object of 4 artists>

# %%
from matplotlib import pyplot as plt
import numpy as np


fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
ax.axis('equal')
langs = ['C', 'C++', 'Java', 'Python', 'PHP']
students = [23, 17, 35, 29, 12]
ax.pie( students, labels = langs, autopct = '%1.2f%%')
plt.show()

# %%
from google.colab import files

uploaded = files.upload()

for fn in uploaded.keys():
  print('User uploaded file "{name}" with length {length} bytes'.format(
      name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-beb6a2ca-3a77-446a-8bfa-8fae1596af31" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-beb6a2ca-3a77-446a-8bfa-8fae1596af31">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving qqq.txt to qqq.txt
# User uploaded file "qqq.txt" with length 13 bytes

# %%
import matplotlib.pyplot as plt
with open('qqq.txt') as f:
    data = f.read()
data = data.split('\n')
x = [row.split(' ')[0] for row in data]
y = [row.split(' ')[1] for row in data]
plt.plot(x, y)
plt.xlabel('ось Х')
plt.ylabel('ось Y')
plt.title('Данные из файла')
plt.show()

# %%
from google.colab import files


uploaded = files.upload()

for fn in uploaded.keys():
    print('User uploaded file "{name}" with length {length} bytes'.format(
        name=fn, length=len(uploaded[fn])))
# Out:
#      <input type="file" id="files-f576f8b8-60b3-4895-bb35-f910b4784722" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f576f8b8-60b3-4895-bb35-f910b4784722">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving test1.xlsx to test1 (1).xlsx
# User uploaded file "test1.xlsx" with length 7762 bytes

# %%
import matplotlib.pyplot as plt
import pandas as pd
df = pd.read_csv('fdata.csv', sep=',', parse_dates = True, index_col = 0)
df.plot()
plt.show()
